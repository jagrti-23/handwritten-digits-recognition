# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv("mnist_train.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 785 entries, label to 28x28
# dtypes: int64(785)
# memory usage: 359.3 MB

# %%
train=data.iloc[0:30000,1:].values
train_label=data.iloc[0:30000,0].values

# %%
classifier=KNeighborsClassifier(7)
classifier.fit(train,train_label)
a=test[3]
a.shape=(28,28)
plt.imshow(a)
plt.show()

# %%
test=data.iloc[30000:35000,1:].values
test_label=data.iloc[30000:35000,0].values

# %%
test_pred=classifier.predict(test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(test_label,test_pred)
# Out:
# 0.9572

# %%
from sklearn.metrics import confusion_matrix

# %%
test_pred.shape
# Out:
# (5000,)

# %%
test_label.shape
# Out:
# (5000,)

# %%
confusion_matrix(test_label,test_pred)
# Out:
# array([[468,   1,   0,   0,   0,   0,   3,   1,   0,   0],
#        [  0, 574,   1,   2,   0,   0,   0,   2,   0,   0],
#        [  7,   2, 464,   1,   2,   1,   2,   7,   0,   0],
#        [  2,   0,   4, 476,   0,   8,   1,   5,   4,   3],
#        [  1,   6,   0,   1, 461,   0,   4,   2,   1,   8],
#        [  2,   6,   1,   8,   1, 418,   5,   0,   0,   0],
#        [  2,   1,   0,   0,   0,   4, 483,   0,   0,   0],
#        [  1,   7,   1,   1,   2,   0,   0, 502,   1,  10],
#        [  0,  10,   1,  16,   4,  19,   2,   3, 436,   7],
#        [  3,   0,   0,   5,   1,   1,   0,   6,   1, 504]])

# %%
clf2 = DecisionTreeClassifier()
clf2.fit(train,train_label)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
test_pred1=clf2.predict(test)

# %%
accuracy_score(test_label,test_pred1)
# Out:
# 0.8404

# %%
from sklearn.ensemble import RandomForestClassifier
clf2= RandomForestClassifier(10)
clf2.fit(train,train_label)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
test_pred2=clf2.predict(test)

# %%
accuracy_score(test_label,test_pred2)
# Out:
# 0.9322

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(train,train_label)
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
test_pred=classifier.predict(test)

# %%
accuracy_score(test_label,test_pred)
# Out:
# 0.5536

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'rbf', random_state = 0)
classifier.fit(train, train_label)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=0, shrinking=True, tol=0.001,
#     verbose=False)

# %%
test_pred=classifier.predict(test)

# %%
accuracy_score(test_label,test_pred)
# Out:
# 0.9702
